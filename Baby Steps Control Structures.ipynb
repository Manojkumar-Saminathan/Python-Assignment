# %%
print('Welcome to Assignments-1')
# Out:
# Welcome to Assignments-1

# %%
Num1=10
Num2=30
Add=40
print('Num1=',Num1)
print('Num2=',Num2)
print('Add',Add)
# Out:
# Num1= 10
# Num2= 30
# Add 40

# %%
BMI=float(input('Enter the BMI Index'))
if(BMI<18.5):
    print('underweight')
elif(BMI<=24.9):
    print('Normal Weight')
elif(BMI<=29.9):
    print('overweight')
else:
    print('obese')
# Out:
# Enter the BMI Index 29.9
# overweight
