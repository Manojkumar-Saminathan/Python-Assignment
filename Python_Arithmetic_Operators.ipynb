# %%
print('HOPE AI')
# Out:
# HOPE AI

# %%
Institute_Name=input('Enter Your Institute Name? :')
# Out:
# Enter Your Institute Name? : HOPE AI

# %%
Name=input('Enter Your Name:')
Age=int(input('Enter Your Age:'))
School=input('Enter Your School:')
Degree=input('Enter Your Degree:')
# Out:
# Enter Your Name: Test
# Enter Your Age: 30
# Enter Your School: Test
# Enter Your Degree: B.E

# %%
print('add =',int(input('a='))+int(input('b=')))
# Out:
# a= 43
# b= 34
# add = 77

# %%
print('sub =',int(input('a='))-int(input('b=')))
# Out:
# a= 43
# b= 34
# sub = 9

# %%
print('mul =',int(input('a='))*int(input('b=')))
# Out:
# a= 63
# b= 97
# mul = 6111

# %%
print('Float div =',int(input('a='))/int(input('b=')))
# Out:
# a= 76
# b= 31
# Float div = 2.4516129032258065

# %%
print('Floor div =',int(input('a='))//int(input('b=')))
# Out:
# a= 76
# b= 31
# Floor div = 2

# %%
print('Modulo =',int(input('a='))%int(input('b=')))
# Out:
# a= 76
# b= 31
# Modulo = 14

# %%
print('Power =',int(input('a='))**int(input('b=')))
# Out:
# a= 4
# b= 4
# Power = 256

# %%
x = 10
y = 3

print('Addition',x + y)
print('Subtraction',x - y)
print('Multiplication',x * y)
print('Division',x / y)
print('Modulus',x % y)
print('Exponentiation',x ** y)
print('Floor division',x // y)
# Out:
# Addition 13
# Subtraction 7
# Multiplication 30
# Division 3.3333333333333335
# Modulus 1
# Exponentiation 1000
# Floor division 3
