# %%
#syntex
if():
    print()
elif():
    print()
else:
    print()

# %%
age=int(input('Enter Your Age'))
if(age<18):
    print('children')
else:
    print('Adult')
# Out:
# Enter Your Age 17
# children

# %%
age=int(input('Enter Your Age'))
if(age<18):
    print('children')
    print('if')
elif(age<45):
    print('Adult')
elif(age<60):
    print('citizen')
else:
    print('Senior Citizen')
# Out:
# Enter Your Age 61
# Senior Citizen
